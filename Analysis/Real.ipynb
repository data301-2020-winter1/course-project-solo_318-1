# %%
import pandas as pd
df = pd.read_csv(r'\Users\john\Desktop\course-project-solo_318-1\Analysis\listings(2).csv')
df
# Out:
#              id                                               name    host_id  \
# 0          1419                    Beautiful home in amazing area!       1565
# 1          8077                 Downtown Harbourfront Private Room      22795
# 2         12604                     Seaton Village Parlour Bedroom      48239
# 3         23691                    Queen Bedroom close to downtown      93825
# 4         26654  World Class downtown @CN Tower Theatre MTCC ga...     113345
# ...         ...                                                ...        ...
# 19338  45348297                Studio Condo in Downtown Toronto #5  342316738
# 19339  45351124                         budget friendly nice place  342346982
# 19340  45351175                     affordable, long term place :)  342346982
# 19341  45351235                    Studio Unit with a nice view :)  342346982
# 19342  45351322               Luxury Studio Condo Amazing LakeView   38189462
#
# ...

# %%
import pandas as pd
import numpy as np

df1 = (pd.read_csv(r'\Users\john\Desktop\course-project-solo_318-1\Analysis\listings(2).csv')
          .rename(columns={"id": "Property_id"})
          .rename(columns={"name": "Property_name"})
          .reset_index(drop=True) )
df2 = (
            df1
            .sort_values("price", ascending=True)
            .drop(columns=['neighbourhood_group'])
            .drop(columns=['longitude', 'latitude'])
            .dropna()
     
           )
df2


    # Make sure to return the latest dataframe

# %%
from Scripts import poject # This is called a relative import
df = poject.load_and_process(r'\Users\john\Desktop\course-project-solo_318-1\Analysis\listings(2).csv')
df.head()
# Out:
#    Property_id                                      Property_name  host_id  \
# 0         1419                    Beautiful home in amazing area!     1565
# 1         8077                 Downtown Harbourfront Private Room    22795
# 3        23691                    Queen Bedroom close to downtown    93825
# 4        26654  World Class downtown @CN Tower Theatre MTCC ga...   113345
# 5        27423        Executive Studio Unit- Ideal for One Person   118124
#
#         host_name                      neighbourhood        room_type  price  \
# 0       Alexandra                    Little Portugal  Entire home/apt    469
# 1  Kathie & Larry  Waterfront Communities-The Island     Private room     99
# 3   Yohan & Sarah               Briar Hill-Belgravia     Private room     70
# 4           Adela  Waterfront Communities-The Island  Entire home/apt    135
# 5           Brent                  Greenwood-Coxwell  Entire home/apt     54
#
# ...

# %%
import pandas as pd
import numpy as np

df1 = (pd.read_csv(r'\Users\john\Desktop\course-project-solo_318-1\Analysis\listings(2).csv')
       .rename(columns={"id": "Property_id"})
       .rename(columns={"name": "Property_name"})
       .reset_index(drop=True) 
       .sort_values("price", ascending=True)
       .drop(columns=['neighbourhood_group'])
       .drop(columns=['longitude', 'latitude'])
       .dropna()
      )
df1
            
            
           

    # Make sure to return the latest dataframe
# Out:
#        Property_id                                      Property_name  \
# 17631     43036342    Modern Suite + Free Parking, atop Union Station
# 5928      19242082  Peaceful home, right by subway station (401, 404)
# 4784      16100281                 Futon/Couch in Davisville, Toronto
# 11931     32901058        Cozy bunkbed in a warm and charming bedroom
# 16951     42017267       Comfy bunkbed in a cozy shared room near TTC
# ...            ...                                                ...
# 8110      23416911      Luxury Loft, in the heart of downtown Toronto
# 15918     40311257                  Awesome loft in centre of Toronto
# 16289     40845163      Heart of Downtown Toronto & Amazing Lake View
# 10136     28615622   Amazing furnished clean home Free parking + Wifi
# 6659      20653172           Modern Upscale Condo in downtown Toronto
#
#          host_id         host_name                      neighbourhood  \
# ...

# %%
from Scripts import cold 
df = cold.load_and_process(r'\Users\john\Desktop\course-project-solo_318-1\Analysis\listings(2).csv')
df

# %%
from Scripts import bold
df = bold.load_and_process(r'\Users\john\Desktop\course-project-solo_318-1\Analysis\listings(2).csv')
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-d2a37ca49317> in <module>
#       1 from Scripts import bold
# ----> 2 df = bold.load_and_process(r'\Users\john\Desktop\course-project-solo_318-1\Analysis\listings(2).csv')
#       3 df
#
# AttributeError: module 'Scripts.bold' has no attribute 'load_and_process'

# %%
from Scripts import bold 
df = bold.load_and_process(r'\Users\john\Desktop\course-project-solo_318-1\Analysis\listings(2).csv')
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-83c8d0e2909a> in <module>
#       1 from Scripts import bold
# ----> 2 df = bold.load_and_process(r'\Users\john\Desktop\course-project-solo_318-1\Analysis\listings(2).csv')
#       3 df
#
# AttributeError: module 'Scripts.bold' has no attribute 'load_and_process'
